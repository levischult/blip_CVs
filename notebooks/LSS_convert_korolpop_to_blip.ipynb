# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import legwork as lw
import astropy.coordinates as cc
import astropy.units as u
import healpy as hp

# %%
file = '/home/levis/lisa_projects/blip_CVs/datasets/dwd_datasets/DWD_obs_based_population_N26940000.txt'

# %%
dwd_arr = np.loadtxt(file, skiprows=1)

# %%
colnames = ['f [Hz]', 'dfdt [Hz/s]', 'AmpPN0', 'lambda_ecl [rad,0:2pi)', 'beta_ecl [rad]', 'inc [rad]', 'psi [rad]', 'phi0 [rad]']
dwd_df = pd.DataFrame(dwd_arr, columns=colnames)

# %%
blip_df = dwd_df[['f [Hz]', 'AmpPN0', 'beta_ecl [rad]', 'lambda_ecl [rad,0:2pi)']]

# %%
blip_df.rename(columns={'f [Hz]': 'f', 'AmpPN0': 'h', 'beta_ecl [rad]': 'lat', 'lambda_ecl [rad,0:2pi)': 'long'}, inplace=True)
blip_df
# Out:
# /tmp/ipykernel_28120/2027264608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blip_df.rename(columns={'f [Hz]': 'f', 'AmpPN0': 'h', 'beta_ecl [rad]': 'lat', 'lambda_ecl [rad,0:2pi)': 'long'}, inplace=True)
#                  f             h       lat      long
# 0         0.000403  3.298842e-23  0.146572  4.784025
# 1         0.000888  1.404516e-23  0.115749  4.776624
# 2         0.000375  1.177584e-23 -0.293381  4.497074
# 3         0.000224  1.890133e-24 -0.897225  3.915369
# 4         0.000310  4.435266e-24 -0.116236  4.610469
# ...            ...           ...       ...       ...
# 26939995  0.000141  1.377105e-23 -1.218840  3.021510
# 26939996  0.000146  5.531811e-24 -0.312387  4.560358
# 26939997  0.000184  9.425865e-24 -0.055411  4.650220
# ...

# %%
datapath = '/home/levis/lisa_projects/blip_CVs/datasets/dwd_datasets/'
blip_df.to_csv(datapath+'korol22_bmecl.txt',index=False,sep=' ',header=False)
